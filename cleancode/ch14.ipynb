# %% [markdown]
# # hanoitower
#
# ```sh
# >>> import towerofhanoi
# >>> help(towerofhanoi)
# ```

# %%
import towerofhanoi
help(towerofhanoi)
# Out:
# Help on module towerofhanoi:
#
# NAME
#     towerofhanoi - cleancode.towerofhanoi의 Docstring
#
# FUNCTIONS
#     displayDisk(width)
#         주어진 witdh로 원판을 표시한다. width가 0이면 원판이 없을을 의미한다.
#
#     displayTowers(towers)
#         세 탑에 배치된 원판을 표시한다.
#
#     getPlayerMove(towers)
#         플레이어에게 이동 명령을 요청한다. (fromTower, toTower)를 반환한다.
#
#     main()
#         execute the Tower of Hanoi solution
#
# DATA
#     SOLVED_TOWER = [5, 4, 3, 2, 1]
#     TOTAL_DISKS = 5
#
# FILE
#     /Users/donghun2/workspace/oject_oriented_python/cleancode/towerofhanoi.py
